# %%
import pandas as pd
import numpy as np
from deep_translator import GoogleTranslator
from geopy.geocoders import Nominatim
pd.set_option('display.max_rows', None)

def print_data(data,rows=5):
    display(data.head(rows))

# %%
def load_json_data():
    df = pd.read_json('supplier_car.json') 
    return df

# %%
def clean_sort_data(data):
    df = data.drop(['entity_id'], axis=1).sort_values(['ID','Attribute Names'])
    return df

# %%
def explore_data(data):
    print_data(data)
    display(data['ID'].unique().size)
    display(data['Attribute Names'].unique().size)
    display(data.shape)

# %%
def split_pivot_data(data):  
    df1 = data[['ID','MakeText','TypeName','TypeNameFull','ModelText','ModelTypeText']].drop_duplicates().set_index('ID')
    print_data(data)
    display(df1.shape)
        
    df2 = data.pivot(index='ID', columns='Attribute Names', values='Attribute Values').reset_index().rename_axis(None, axis=1).set_index('ID')
    print_data(df2)
    display(df2.shape)
    
    return df1, df2

# %%
def merge_data(dx,dy): 
    data = dx.merge(dy, on='ID')
    print_data(data)
    display(data.shape)
    return data

# %%
def map_to_target_data(data):
    return data[
    ['BodyTypeText',
     'BodyColorText',
     'ConditionTypeText',
     'City',
     'MakeText',
     'FirstRegYear',
     'Km',
     'ModelText',
     'ModelTypeText',
     'FirstRegMonth',
    'ConsumptionTotalText']].rename(columns={
                      'BodyTypeText' :'carType',
                      'ConditionTypeText':'condition',
                      'BodyColorText':'color',
                      'City':'city',
                      'MakeText':'make',
                      'FirstRegYear':'manufacture_year',
                      'Km':'mileage',
                      'ModelText':'model',
                      'ModelTypeText':'model_variant',
                      'FirstRegMonth':'manufacture_month',
                      'ConsumptionTotalText':'fuel_consumption_unit'})

# %%
def translate(column):
    items_de = final[~final[column].isna()][column].unique()
    items = {}
    for x in items_de:
        items[x] = GoogleTranslator(source='de', target='en').translate(color).capitalize()
    return items

# %%
def normalize_data(data):
    
    colors = translate['color']
    carTypes = translate['carType']
    conditions = translate['condition']
    
    data['color']=final['color'].apply(lambda x: colors[x] if colors.get(x) != None else x)
    data['carType']=final['carType'].apply(lambda x: carTypes[x] if carTypes.get(x) != None else x)
    data['condition']=final['condition'].apply(lambda x: conditions[x] if conditions.get(x) != None else x)
    data['fuel_consumption_unit']=final['fuel_consumption_unit'].apply(lambda x: 'l_km_consumption' if 'l/100km' in x else x)

    return data

# %%
if __name__ == '__main__':
    
    data = load_json_data()
    print_data(data)
    
    #1. Pre-processing
    data_cleaned = clean_sort_data(data)
    explore_data(data)
    dx,dy = split_pivot_data(data)
    pre_procesed_data = merge_data(dx,dy)
    
    #2. Normalisation
    mapped_data = map_to_target_data(pre_procesed_data)
    print_data(mapped_data)
    display(mapped_data.shape)
    normalized_data = normalize_data(mapped_data)
# Out:
#      ID       MakeText              TypeName  \
# 0   976  MERCEDES-BENZ               McLaren
# 1  1059  MERCEDES-BENZ    ML 350 Inspiration
# 2   524           AUDI  S6 Avant quattro 4.2
# 3   608           SAAB   9-3 2.0i-16 TS Aero
# 4   726        PORSCHE      911 Turbo Cabrio
#
#                        TypeNameFull ModelText         ModelTypeText  \
# 0         MERCEDES-BENZ SLR McLaren       SLR           SLR McLaren
# 1  MERCEDES-BENZ ML 350 Inspiration    ML 350    ML 350 Inspiration
# 2         AUDI S6 Avant quattro 4.2        S6  S6 Avant quattro 4.2
# 3          SAAB 9-3 2.0i-16 TS Aero       9-3   9-3 2.0i-16 TS Aero
# 4          PORSCHE 911 Turbo Cabrio       911      911 Turbo Cabrio
#
#   Attribute Names Attribute Values                             entity_id
# 0           Seats                2  0001fda6-192b-46a8-bc08-0e833f904eed
# 1              Hp              235  00107c2d-0071-4475-88f0-810133638b7e
# 2    FuelTypeText           Benzin  00126794-a8ef-48fe-93d6-43cfc69fbfb6
# 3             Ccm             1985  00182529-1bf7-4f93-89fa-2e8e634b2c9d
# 4   BodyColorText     schwarz mét.  002d30c2-43f6-4905-868f-160dbc445c56
#      ID       MakeText              TypeName  \
# 0   976  MERCEDES-BENZ               McLaren
# 1  1059  MERCEDES-BENZ    ML 350 Inspiration
# 2   524           AUDI  S6 Avant quattro 4.2
# 3   608           SAAB   9-3 2.0i-16 TS Aero
# 4   726        PORSCHE      911 Turbo Cabrio
#
#                        TypeNameFull ModelText         ModelTypeText  \
# 0         MERCEDES-BENZ SLR McLaren       SLR           SLR McLaren
# 1  MERCEDES-BENZ ML 350 Inspiration    ML 350    ML 350 Inspiration
# 2         AUDI S6 Avant quattro 4.2        S6  S6 Avant quattro 4.2
# 3          SAAB 9-3 2.0i-16 TS Aero       9-3   9-3 2.0i-16 TS Aero
# 4          PORSCHE 911 Turbo Cabrio       911      911 Turbo Cabrio
#
#   Attribute Names Attribute Values                             entity_id
# 0           Seats                2  0001fda6-192b-46a8-bc08-0e833f904eed
# 1              Hp              235  00107c2d-0071-4475-88f0-810133638b7e
# 2    FuelTypeText           Benzin  00126794-a8ef-48fe-93d6-43cfc69fbfb6
# 3             Ccm             1985  00182529-1bf7-4f93-89fa-2e8e634b2c9d
# 4   BodyColorText     schwarz mét.  002d30c2-43f6-4905-868f-160dbc445c56
# 1153
# 19
# (21906, 9)
#      ID       MakeText              TypeName  \
# 0   976  MERCEDES-BENZ               McLaren
# 1  1059  MERCEDES-BENZ    ML 350 Inspiration
# 2   524           AUDI  S6 Avant quattro 4.2
# 3   608           SAAB   9-3 2.0i-16 TS Aero
# 4   726        PORSCHE      911 Turbo Cabrio
#
#                        TypeNameFull ModelText         ModelTypeText  \
# 0         MERCEDES-BENZ SLR McLaren       SLR           SLR McLaren
# 1  MERCEDES-BENZ ML 350 Inspiration    ML 350    ML 350 Inspiration
# 2         AUDI S6 Avant quattro 4.2        S6  S6 Avant quattro 4.2
# 3          SAAB 9-3 2.0i-16 TS Aero       9-3   9-3 2.0i-16 TS Aero
# 4          PORSCHE 911 Turbo Cabrio       911      911 Turbo Cabrio
#
#   Attribute Names Attribute Values                             entity_id
# 0           Seats                2  0001fda6-192b-46a8-bc08-0e833f904eed
# 1              Hp              235  00107c2d-0071-4475-88f0-810133638b7e
# 2    FuelTypeText           Benzin  00126794-a8ef-48fe-93d6-43cfc69fbfb6
# 3             Ccm             1985  00182529-1bf7-4f93-89fa-2e8e634b2c9d
# 4   BodyColorText     schwarz mét.  002d30c2-43f6-4905-868f-160dbc445c56
# (1153, 5)
#    BodyColorText        BodyTypeText   Ccm    City Co2EmissionText  \
# ID
# 1      anthrazit           Limousine  3199  Zuzwil        275 g/km
# 2      anthrazit               Kombi  4991  Zuzwil        333 g/km
# 3      anthrazit               Kombi  4172  Zuzwil        350 g/km
# 4      anthrazit               Coupé  6162  Zuzwil        291 g/km
# 5      anthrazit  SUV / Geländewagen  4806  Zuzwil        270 g/km
#
#    ConditionTypeText ConsumptionRatingText ConsumptionTotalText Doors  \
# ID
# 1           Occasion                  null         11.5 l/100km     4
# 2           Occasion                     G         14.0 l/100km     5
# 3           Occasion                     G         14.6 l/100km     5
# 4           Occasion                     G         12.7 l/100km     2
# 5           Occasion                     G         11.5 l/100km     5
#
#        DriveTypeText FirstRegMonth FirstRegYear FuelTypeText   Hp  \
# ID
# 1             Allrad             1         1999       Benzin  224
# 2             Allrad             7         2008       Benzin  580
# 3             Allrad            10         2002       Benzin  450
# 4   Hinterradantrieb             6         2015       Benzin  660
# 5             Allrad             1         2010       Benzin  500
#
#    InteriorColorText     Km                          Properties Seats  \
# ID
# 1               grau  31900                            "Ab MFK"     5
# 2               null  25400                            "Ab MFK"     5
# 3              beige  38500                            "Ab MFK"     5
# 4            schwarz    200  "Ab MFK", "Direkt-/Parallelimport"     2
# 5            schwarz   2900                            "Ab MFK"     5
#
#       TransmissionTypeText
# ID
# 1                  Automat
# 2      Automat sequentiell
# 3      Automat sequentiell
# 4   Schaltgetriebe manuell
# 5      Automat sequentiell
# (1153, 19)
#            MakeText              TypeName                      TypeNameFull  \
# ID
# 976   MERCEDES-BENZ               McLaren         MERCEDES-BENZ SLR McLaren
# 1059  MERCEDES-BENZ    ML 350 Inspiration  MERCEDES-BENZ ML 350 Inspiration
# 524            AUDI  S6 Avant quattro 4.2         AUDI S6 Avant quattro 4.2
# 608            SAAB   9-3 2.0i-16 TS Aero          SAAB 9-3 2.0i-16 TS Aero
# 726         PORSCHE      911 Turbo Cabrio          PORSCHE 911 Turbo Cabrio
#
#      ModelText         ModelTypeText BodyColorText        BodyTypeText   Ccm  \
# ID
# 976        SLR           SLR McLaren   silber mét.           Cabriolet  5439
# 1059    ML 350    ML 350 Inspiration   silber mét.  SUV / Geländewagen  3724
# 524         S6  S6 Avant quattro 4.2       schwarz               Kombi  4170
# 608        9-3   9-3 2.0i-16 TS Aero  schwarz mét.           Limousine  1985
# 726        911      911 Turbo Cabrio  schwarz mét.           Cabriolet  3600
#
#         City Co2EmissionText  ...     DriveTypeText FirstRegMonth  \
# ID                            ...
# 976   Zuzwil            null  ...  Hinterradantrieb            10
# 1059  Zuzwil        305 g/km  ...            Allrad            10
# 524   Zuzwil        353 g/km  ...            Allrad             6
# 608   Zuzwil        216 g/km  ...  Vorderradantrieb             9
# 726   Zuzwil        309 g/km  ...            Allrad             4
#
#      FirstRegYear FuelTypeText   Hp InteriorColorText      Km Properties  \
# ID
# 976          2007       Benzin  626           schwarz   29800   "Ab MFK"
# 1059         2003       Benzin  235           schwarz  126300   "Ab MFK"
# 524          1997       Benzin  290             beige   91900   "Ab MFK"
# 608          2001       Benzin  205           schwarz  134600   "Ab MFK"
# 726          2008       Benzin  480             braun   35500   "Ab MFK"
#
#      Seats    TransmissionTypeText
# ID
# 976      2      Automatik-Getriebe
# 1059     5                 Automat
# 524      5                 Automat
# 608      5  Schaltgetriebe manuell
# 726      2  Schaltgetriebe manuell
#
# [5 rows x 24 columns]
# (1153, 24)
#                  carType         color condition    city           make  \
# ID
# 976            Cabriolet   silber mét.  Occasion  Zuzwil  MERCEDES-BENZ
# 1059  SUV / Geländewagen   silber mét.  Occasion  Zuzwil  MERCEDES-BENZ
# 524                Kombi       schwarz  Occasion  Zuzwil           AUDI
# 608            Limousine  schwarz mét.  Occasion  Zuzwil           SAAB
# 726            Cabriolet  schwarz mét.  Occasion  Zuzwil        PORSCHE
#
#      manufacture_year mileage   model         model_variant manufacture_month  \
# ID
# 976              2007   29800     SLR           SLR McLaren                10
# 1059             2003  126300  ML 350    ML 350 Inspiration                10
# 524              1997   91900      S6  S6 Avant quattro 4.2                 6
# 608              2001  134600     9-3   9-3 2.0i-16 TS Aero                 9
# 726              2008   35500     911      911 Turbo Cabrio                 4
#
#      fuel_consumption_unit
# ID
# 976                   null
# 1059          12.7 l/100km
# 524           14.9 l/100km
# 608            9.0 l/100km
# 726           12.9 l/100km
# (1153, 11)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-bec070f5b887> in <module>
#      14     print_data(mapped_data)
#      15     display(mapped_data.shape)
# ---> 16     normalized_data = normalize_data(mapped_data)
#      17
#
# <ipython-input-9-b36a007fa25e> in normalize_data(data)
#       1 def normalize_data(data):
#       2
# ----> 3     colors = translate['color']
#       4     carTypes = translate['carType']
#       5     conditions = translate['condition']
#
# TypeError: 'function' object is not subscriptable
