# %%
import advertools as adv
import pandas as pd
#adv.crawl('https://datacamp.com', 'my_output_file.jl', follow_links=True)

# %%
crawl_df = pd.read_json('my_output_file.jl', lines=True)
display(crawl_df.head(20))
# Out:
#                                                   url  \
# 0                           https://www.datacamp.com/
# 1   https://www.datacamp.com/courses/connecting-da...
# 2   https://www.datacamp.com/courses/intermediate-...
# 3   https://www.datacamp.com/courses/cleaning-data...
# 4   https://www.datacamp.com/courses/introduction-...
# 5   https://www.datacamp.com/courses/cleaning-data...
# 6   https://www.datacamp.com/courses/web-scraping-...
# 7   https://www.datacamp.com/courses/streamlined-d...
# 8   https://www.datacamp.com/data-courses/data-ana...
# 9   https://www.datacamp.com/courses/introduction-...
# 10  https://support.datacamp.com/hc/en-us/articles...
# 11                  https://www.datacamp.com/security
# 12  https://assets.datacamp.com/production/reposit...
# 13             https://www.datacamp.com/accessibility
# 14  https://www.datacamp.com/do-not-sell-my-person...
# 15  https://assets.datacamp.com/production/reposit...
# ...
